# %% [markdown]
# # Computational modeling of goal-directed and habitual reinforcement-learning strategies
#
# Claire Smid<sup>1</sup> and Wouter Kool<sup>2</sup><br>
# <sub><sup>1</sup> University College London<br>
# <sup>2</sup> Washington University in St. Louis<br></sub>
#
# **Useful references:**
#
# Free lecture series from David Silver on reinforcement learning: https://www.youtube.com/watch?v=2pWv7GOvuf0
#
# - Sutton and Barto 2nd edition: http://incompleteideas.net/book/the-book-2nd.html
# - Drummond, N., & Niv, Y. (2020). Model-based decision making and model-free learning. _Current Biology, 30,_ R860-R865.
# - Daw, N. D., Gershman, S. J., Seymour, B., Dayan, P., & Dolan, R. J. (2011). Model-based influences on humans' choices and striatal prediction errors. _Neuron, 69,_ 1204-1215.
# - Doll, B. B., Duncan, K. D., Simon, D. A., Shohamy, D., & Daw, N. D. (2015). Model-based choices involve prospective neural activity. _Nature Neuroscience, 18,_ 767-772.
# - Kool, W., Cushman, F. A., & Gershman, S. J. (2016). When does model-based control pay off? _PLoS Computational Biology, 12,_ e1005090.
# - Decker, J. H., Otto, A. R., Daw, N. D., & Hartley, C. A. (2016). From creatures of habit to goal-directed learners: Tracking the developmental emergence of model-based reinforcement learning. Psychological science, 27(6), 848-858.

# %% [markdown]
# ### Goal of this workshop
#
# In this workshop, you are going to explore a computational model that makes decisions using two distinct reinforcement-learning strategies.
#
# The first of these is an agent that learns the value of actions in the environment solely by observing their associated _rewards_ and _punishments_. This strategy, which resembles Skinner's operant conditioning principles, is extremely efficient and has virtually no deliberation by the agent. It simply repeats what worked in the past, and avoids what did not. We think of this type of decision making as more-or-less *habitual*.
#
# However, humans, and other animals, often make more sophisticated decisions, using the structure of the environment to their advantage. This was shown famously by Edward Tolman. He trained mice to find a reward in a simple maze, always starting them from the same location. Of course, these mice quickly found the most efficient way to the reward. This result is, of course, easily explainable with operant conditioning. However, when Tolman placed his rats in another arm of the maze, he found that they were still very good at walking towards the rewarded location. This suggests that the rats formed a _cognitive map_ of the task, an internal representation of the structure of the maze, and that they used this to plan towards their goal. This type of decision making can be thought of as *goal-directed* or *deliberative*.
#
# Humans also form cognitive maps of their environment, and they use these to plan towards their goals. Some of these cognitive maps can be of actual physical space (such as when planning your route home), but cognitive maps can be very abstract as well (for example, of your social network!).

# %% [markdown]
# <mark>Can you think of a real-life scenario in which you rely more on habit, and one in which you use more goal-directed planning?
# <br>
#
# In this workshop, we will build models that use both habitual and goal-directed decision-making strategies. You are going to do this in the context of a variant (Kool et al. 2016, Doll et al. 2015) of a popular sequential decision-making task (one where participants make multiple decisions as they navigate through the environment to achieve a reward, (Daw et al. 2011)). We are going to (1) simulate and inspect behavior of the computational model, and (2) use model-fitting techniques to fit data to the task.
#
# We hope that these lessons inspire you to start using computational models in your own work! Mathematical descriptions of computational models can be daunting to the untrained eye. By letting you play around with the models, and by providing a scaffold from which to work, we aspire to show you that most of the computational models that psychologists use are fairly simple and that you can leverage their precision to gain a mathematically precise peak under the mind's hood.

# %% [markdown]
# ## Notation and some words of advice
#
# This workshop, like all computer code, works from top to the bottom. We will use plain text (like this) to inform you about aspects of the task, computational models, and model-fitting techniques. Often, we will provide you with some unfinished code, and it will be your task to complete it. To make this workshop more focused, you will not write _all_ of the code. Instead, we are going to focus your attention on the parts of the model that we think is most important for your understanding of how to use reinforcement learning to study human behavior.
# <br>
#
# <mark> When we have an assignment for you, we will print it in yellow. Like this. You have already seen an example of this in the paragraph above.</mark>
#
# We will also provide **Hints** for you in bold, that can give you some pointers of how to approach a problem.

# %% [markdown]
# ### Overview
# The workshop contains three sections. In the first (this notebook), you will learn about the task, some of the basic building blocks of reinforcement-learning models, and you will simulate behavior of an agent that acts purely with the habitual decision-making strategy. In the second, you will add the goal-directed decision-making strategy to this code, and you will learn how let the agent act according to a _mixture_ of these two 'systems'. In the third section, we will teach you how to fit the model's parameters to data. We have tried our best to structure the coding assignments so that you start with very small tasks, and then work your way to a real, working, simulation of how humans might perform in a psychological experiment.
#
# This workshops will require you to code. We encourage you to play around with the code. Create a new cell to see what certain lines of code produce, try to figure out how important functions work, and mess around with parameter values! Getting your hands dirty will really help you truly understand the computational models described in this workshop.
#
# ### Jupyter Notebook/Google Colab shortcuts
# This workshop is coded using Python. You can edit it and run the code using either **Jupyter Notebook** or **Google Colab**. Jupyter Notebook can be easily installed using Anaconda: https://www.anaconda.com/. Google Colab: https://colab.research.google.com/ is easily accessible from your browser, and has the benefit that all packages will be available to you directly. However, you can only have 5 Google Colab notebooks running at a time, while this is unlimited for Jupyter Notebook. Both are freely accessible!
#
# Just to get you started:
#
# - Press shift + enter to go through each cell and run the code that is in it
# - Whenever you see a # in front of a line of code, this means that the following text are just comments and not actual code
# - If you see a * like In[*] to the left of the cell, it means the cell is still running
# - In the top right of the screen you can see what language you're coding in (it should say Python 3)
# - The number inside the In[] bracket shows when you ran this cell last (e.g. if it says In[1], this is the first cell you've ran (the order doesn't really matter, you can rerun cells as often as you like. This just shows you in which order the cells were run.
# - If there are any kind of functions in the cells, you need to run the cell before you can use it in the rest of the notebook
#
# If you want to learn more shortcuts for navigating Jupyter Notebook/Google Colab, here is a useful link: https://towardsdatascience.com/jypyter-notebook-shortcuts-bf0101a98330
#
# **Important:** If you do not understand a piece of code, you should _definitely_ create a new cell somewhere in this Notebook. (+ sign in the top) and copy the code and run it individually. This a perfect way to gain insight into how lines of code work. It will allow you to mess around and <code>print</code> the output of variables without the risk of ruining your prior work. We do this all the time.

# %% [markdown]
# # Section 1: the paradigm, value-based choice, and model-free reinforcement learning
# ## The two-step task
# We are going to simulate reinforcement-learning perform a variant of popular paradigm known as the 'two-step' task. In this task, participants have to make repeated decisions in order to receive a reward. To make the task more fun for our participants, we have embedded the task in a space travel setting! On each trial of the task participants choose one spaceship from a pair of spaceships. The chosen spaceship then takes the participant to either a red or a purple planet. There they encounter an alien. If the participant interacts with the alien, there is chance that they will receive a reward in the form of space treasure!
#
# Specifically, there are two pairs of spaceships that each appear in their own 'first-stage' state. For each pair, one spaceship will always transition to the red planet, and the other always to the purple planet. Below is a schematic of this structure, in _cursive_ are the variables we will use to keep track of the different states (s1 and s2) and values for actions (Qmf1 and Qmf2):
#
# ![Task_structure](../Figures/task_structure_text.png)
#
# _Stimuli adapted from Decker et al. 2016_
#
# So each trial starts with seeing one of the two pairs of spaceships (either in the top left or top right panel). In each pair, participant have the opportunity to go to the red or the purple planet. The dark blue and orange spaceships always travel to the red planet, while the green and light blue spaceship always go to the purple planet.
#
# After selecting an alien, the participant either recieves a reward or it does not. This is determined by the current _reward probability_ of each alien. If this probability is high, the alien is likely to deliver a reward, if it is low, the alien is unlikely to deliver a reward. For each of the two aliens, this reward probability changes over time, independently from the other alien's reward probability. This means that participants need to continually learn which planet has the best alien! You can see an example of reward probabilities for each alien across 200 trials of the task. Note that the reward probabilities 'drift' between 0% and 100%.
#
# ![Reward_probabilities](../Figures/drifting_reward_probabilities.png)

# %% [markdown]
# ## Two reinforcement-learning strategies
#
# The neat thing about the two-step task is that it lets researchers dissociate between more habitual and more goal-directed decision-making strategies. We can do so by using tools from reinforcement learning. Specifically, a wealth of research over the last decade suggests that these forms of decision making are described well by ***model-free*** and ***model-based*** reinforcement learning, respectively (for a short introductory piece, see Drummond & Niv, 2020).
#
# ### Model-free reinforcement learning
# A model-free decision maker simply associates the actions it took with the rewards they yielded. It increases the likelihood of choosing actions that led to reward, and decreases the likelihood of choosing actions that led to no reward. In other words, it performs trial-and-error learning. In the two-step task above, this has some interesting implications for how a model-free learner chooses its actions based on what happened on the previous trial.
#
# For example, imagine that a trial starts with the  spaceship pair on the top left in the image above, and that the agent chooses the dark blue spaceship. Therefore, they will transition to red planet. Now let's say that here they receive a reward. The question is how this affects their choice on the next trial. It turns out that this completely depends on which first-stage 'starting state' they encounter on this next trial. There are two possibilities: either they start in the same (top-left) state, or in the other (top-right) state (this is randomly chosen). If the model-free agent starts in the same state as on the previous trial, they will see the same dark-blue spaceship again. Because they have associated the dark-blue spaceship with the reward on the previous trial, the model-free agent will  be more likely to choose this spaceship again! However, if the model-free agent starts in the other starting state, the action chosen on the previous trial (the dark blue spaceship) is not available (you can verify this in the figure above). The outcomes on the previous trial did not involve any of the currently available actions. Therefore, the outcomes on the previous trial do not affect the choices on the current trial.
#
# In short, model-free learners do not generalize experiences between starting states. Because model-free learners simply repeat what worked before, and avoid what didn't, anything learned from one starting state only affects their choice in that same starting state.
#
# ### Model-based reinforcement learning
# Goal-directed control can be modeled using model-based reinforcement learning. The key characteristic of a model-based decision maker is that they use the structure of the environment to _plan towards goals_. In other words, they use their knowledge of how the spaceships transition to planets to infer the expected value of each spaceship. You can think of this in terms of generalization: a model-based learner will view the dark blue and orange spaceships as the same option, and the green and light blue as the same too, because these spaceships lead towards the same planets!
#
# Therefore, a model-based agent evaluates each spaceship in terms of its consequences, and therefore it is able to transfer experiences obtained after one pair of spaceships to the other pair. In the example above this would mean that a model-based agent would not only be more likely to choose the dark-blue spaceship in the same starting state, but also the orange spaceship in the other.
#
# ### Plotting the behavior of model-based and model-free agents.
#
# In the figure below, we have plotted the behavioral profiles of a model-free (left panel) and a model-based agent (right panel). These graphs depict the probability that the agent revisits the same planet as on the previous trial ('stay' probability) as a function of (1) whether or not a reward was received on that trial and (2) whether the starting state is the same as on the previous trial. As you can see, the model-based agent is unaffected by which first-stage state it encounters (right panel). It simply chooses to go to a planet if it earned reward there on the previous trial, regardless of whether the starting state is the same. The model-free learner, on the other hand, is only more likely to revisit the same second-stage state if it encounters the same pair of spaceships.
#
# ![Doll_Stay_Prob_Plots](../Figures/Doll2015_edited_plots_ExamplesOnly.jpg)
#
# _Edited from Doll et al. 2015_

# %% [markdown]
# <mark>It is crucial that you understand the logic of this figure. If it's not clear, you can refer to Doll et al. (2015) or Kool et al. (2016, 2017) for different explanations on these tasks.</mark>
#
# Humans typically display a _mixture_ of these two strategies, as you can see in the figure below. That is, it looks like they are using both model-based and model-free control. Using reinforcement-learning techniques we can figure out how much model-based control each participant uses on this task. That's awesome, because it let's us use precise mathematics to measure a core aspect of human behavior -- how much deliberation and planning is used during decision making.
#
# ![Doll_Human_Prob_Plots](../Figures/Doll_Observed_Only.png)
#
# _Edited from Doll et al. (2015)_
#
# In this workbook we are going to take our first steps towards that. We are going to write some code that implements a model-free learner on this task. With this, we will aim to replicate the left panel of this figure.

# %% [markdown]
# ## Simulating behavior on the two-step task
#
# Finally! We can start looking at some code. First, we are going to import some 'packages' that we will use, including Numpy and Matplotlib. Simply hit shift-enter in the following cell to run the code.

# %%
# first, we'll import some packages that we'll use

import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1. Creating the drifting reward probabilities
# The first thing we will do is to create a _function_ that generates some drifting reward probabilities. For now, we have written this code for you, but please do inspect the code below. This function generates reward probabilities according to a random Gaussian walk. As you can see, the function takes input parameters that dictate the number of trials (<code>n_trials</code>), the upper and lower bounds for the probabilities (<code>bounds</code>), the reward probabilities at which each alien starts (<code>init_vals</code>), and how quickly the reward probabilities change from trial to trial (<code>drift_rate</code>). The function returns an array with reward probabilities for each state and trial number (<code>reward_probs</code>).
#
# You will have to run the cell below to make this function available to this Python notebook, but you will not have to change it.

# %%
# Create drifting reward probabilities 
def generate_rewards(n_trials, bounds, init_vals, drift_rate):
    
    # we can set the same random seed so we get the same random values
    random.seed(2)

    # pre-allocate the rest
    reward_probs = np.ones((n_trials, 2)) * 0.5

    # To start with, we initialise one planet lower than the other
    reward_probs[0,:] = random.sample( init_vals, len(init_vals))

    # next, we loop through the trials, and add Gaussian noise to each planet's reward probability for each trial separately
    for t in np.arange(n_trials-1)+1:

        for state in range(2):

            upd = np.random.normal(0, drift_rate) # random Gaussian noise
            
            reward_probs[t, state] = reward_probs[t-1, state] + upd
            
            # reflecting bounds
            reward_probs[t, state] = min(reward_probs[t, state],max(bounds[1]*2-reward_probs[t, state],bounds[0]))
            reward_probs[t, state] = max(reward_probs[t, state],min(bounds[0]*2-reward_probs[t, state],bounds[1]))
            
    return reward_probs

# %% [markdown]
# In the cell below, we run this function with a particular set of input parameter values. Specifically, we tell it to generate reward probabilities for 200 trials, with bounds of 0 and 1, starting points at 0.4 and 0.6, and with a 'drift rate' of 0.2. Next, we plot the reward probabilities across trials. _Note that because these reward probabilities are randomly generated, they will change everytime you run the above code._ You can play with the different values of the input parameters to see how these affect the reward probabilities.

# %% [markdown]
# <mark>Try to understand how the value of the drift rate parameter changes the reward probabilities!

# %%
## Generate reward probabilities:
n_trials = 200
bounds = [0, 1]
init_vals = [0.4, 0.6]
drift_rate = 0.8 # play around with this value!

reward_probs = generate_rewards(n_trials,bounds,init_vals,drift_rate)
## Make plot:
# Define plot sizes
ax = plt.subplots(figsize=(15, 4), facecolor='w')
ax = plt.subplot2grid((3, 1), (0, 0), colspan=1, rowspan=2)

# Overlay reward values
ax.plot(reward_probs[:, 0], color='#FF0000', alpha=0.9, linestyle='--', label='Red planet')
ax.plot(reward_probs[:, 1], color='#9A0EEA', alpha=0.9, linestyle='--', label='Purple planet')
ax.set_ylabel('Probability of reward')
ax.set_xlabel('Trials')
ax.set_title(r'Drifting reward probabilities', fontweight='bold')
ax.set_ylim(0, 1)
ax.set_xlim(0, n_trials)
ax.legend(loc=1)
plt.show()

# %% [markdown]
# ### Step 2. Choice and update results
# Great! We have a function that gives us reward probabilities that our model-free learner will try to estimate and use to obtain rewards!. Now, we will work towards implementing this model-free reinforcement learner. First, _you_ will write two functions that are going to be very helpful with this enterprise. The first is the _softmax decision rule_, which helps us translate learned values of available actions into choice probabilities! Then, we will talk a little bit about how model-free reinforcement learning updates action values, and implement some code that performs this update according to the _temporal difference update rule_.
#
# #### The softmax decision rule
# In order to make a choice, our reinforcement learner needs to be able to translate values of actions into action probabilities. We are going to do this using the softmax rule. This rule computes the probability of an action by weighing its value against all other values: if an agent values a particular action highly compared to the other actions, it will be more likely to select that action. In math, this rule can be written as:
#
# $\Large p(a') = \frac{e^{\beta Q(a')}}{\sum_j{e^{\beta Q(a_{j})}}}$
#
# with $a'$(a-prime) being the probability of the future action, $Q(a)$ the estimated value of action $a$ and $\beta\geq0$ an inverse temperature parameter. This latter parameter determines the agent's explore/exploit tradeoff. If $\beta$ is large, the agent exploits, and is more likely to choose what it thinks is the best possible option. If its value is closer to 0, then the agent is more likely to explore, and choose more randomly between actions.
#
# The way to read this function is to see it as a way to reflect some transformation of the propotion of _value_ that $a'$ has over all available value. If this value is much higher than all other actions, than this proportion approaches 1, if it is much lower than all other actions, this proportion approaches 0.
#
# To see this, you are going write the softmax function. What we want is a function that returns the choice probabilities for each available action. The function accepts an array with Q-values, and an inverse temperature parameter value.

# %% [markdown]
# <mark>Finish the softmax formula in the cell below. After that, you can use the next cell with code test your function.

# %%
def softmax(Q,beta): 
    
    p = np.exp(beta*Q) / np.sum(np.exp(beta*Q))
    
    return p # here we return the computed reward probabilities

# hint: you should us np.exp, and np.sum. You can multiply numpy arrays with a scalar  using *, 
# and you can divide numbers using /
# Google things you do not understand! Or ask us!

# %% [markdown]
# You can test your softmax function in the cell below. For your convenience, we have provided an array with two action (or Q-) values of (0.6 and 0.3). You can think of these as estimated reward probabilities that the agent expects after choosing that action. Note that the probabilities returned by <code>softmax</code> should sum to one (i.e., all possible choices should be accounted for). Think about how the inverse temperature ($\beta$) should change these values, and verify this with the code below.

# %%
# test your softmax
Q_example = np.array([0.6, 0.3])
beta = 4 # play with this value, and see how this affects choices probabilities
softmax(Q_example,beta)
# Out:
# array([0.76852478, 0.23147522])

# %% [markdown]
# For a more in-depth inspection of how the inverse temperature ($\beta$) influences choice behavior, you can test your softmax function further in the block of code below. This will plot full choice curves for five different $\beta$ values. The x-axis in this plot shows the difference in value between two available actions A and B. So, on the right side of each plot, $Q(A)$ is much larger than $Q(B)$ and on the left $Q(B)$ is much larger than $Q(A)$.

# %% [markdown]
# <mark>Think about how this should translate into the probability of selecting option A, which is plotted on the y-axis. Do your curves make sense? What should happen when the difference in values becomes larger? What should happen when the inverse temperature ($\beta$) becomes larger? Predict what you think you should see, and then test this using the code below. (There is no need to change the code below.)

# %%
# The following line picks 5 values regularly spaced between 0 and 4
_betas = np.linspace(0.0, 4, 5)

fig, axs = plt.subplots(1, _betas.size, figsize=(_betas.size*3, 3))

for beta, ax in zip(_betas, axs):
    x = np.linspace(-1, 1, 100)
    p = np.zeros(x.size)
    for i in range(x.size):
        p[i] = softmax(np.array([0.5+x[i], 0.5-x[i]]), beta)[0]
    ax.plot(x, p, color='k')
    ax.set_ylim(0, 1)
    ax.set_xlim(-1, 1)
    ax.set_xlabel('Q(A)-Q(B)')
    ax.set_title(r'$\beta$ = ' + str(np.around(beta, 2)), fontweight='bold')
    
axs[0].set_ylabel('P(A)')
plt.tight_layout()

# %% [markdown]
# Awesome! If this is the only thing you do today, you have already learned a LOT. Softmax is the most widely used choice rule in computational psychology, so kudos to you. However, there is so much more ground to cover, so let's hurry along.
#
# #### The temporal difference updating rule
#
# Model-free reinforcement-learning agents update their estimates of how good actions are (Q-values) after they observe what kind of outcomes these actions yield. _They do so after each choice._ In model-free reinforcement-learning, an agent figures out how much to update a given action value after choosing it by computing a _reward prediction error_. The reward prediction is the difference between what the agent expected to happen (i.e., the Q-value of the chosen action), and what actually occurred. This latter component consists of (1) the actual, immediate, reward the agent earns ($r$), and (2) how much reward it estimates to receive in the future ($Q'$). So the prediction error can be written as:
#
# $\Large PE = (r + Q') - Q(a_{chosen})$
#
# Note that the terms in the brackets on the left represents what was _observed_ and the right term represents what was _expected_. So this difference represents some form of surprise! It then uses this prediction error to update the value of the chosen action, but only by a small amount. This small amount is also know as the _learning rate_ ($\alpha$). It dictates how much of the PE gets added to the current Q-value of the chosen action:
#
# $\Large Q(a_{chosen}) \leftarrow Q(a_{chosen})+\alpha PE$
#
# Now, you are going to write this temporal difference rule in a new function below. The function accepts a learning rate (<code>alpha</code>), the Q-value of the chosen action (<code>Q_chosen</code>), and the prediction error (<code>PE</code>). It then spits out an updated version of the Q-value of the chosen action (<code>Q_chosen_updated</code>).

# %% [markdown]
# <mark>Finish the temporal difference updating rule below. Again, we have provided a cell for you below this one for you to test this function.

# %%
def td_rule(alpha, Q_chosen, PE):
    
    Q_chosen_updated = Q_chosen + alpha * PE
    
    return Q_chosen_updated

# %% [markdown]
# You can test your temporal difference updating rule in the cell below. For your convenience, we have provided a learning rate (0.1), a chosen Q value (0.4), a Q_prime value (0), a reward (1). Note that Q_prime = 0, which reflects the state at the end of each trial (when there no more steps or future states to visit; see below for more detail).
#
# Use this to test your function. What happens when the learning rate is very low? What happens when the learning rate is very high? What does this mean in psychological terms?

# %%
# try out the temporal difference updating rule below
alpha = 0.01
Q_chosen = 0.4
Q_prime = 0
r = 0.1

# try to complete the prediction error using r, Q_prime, and Q_chosen
PE = (r + Q_prime) - Q_chosen

td_rule(alpha, Q_chosen, PE)
# Out:
# 0.397

# %% [markdown]
# #### A note about the number of updates in the two-step task
#
# The two-step task consists of, uhh, two 'steps'. The first occurs after a spaceship is chosen and the planet is visited. The second step occurs after the alien gets selected, and the reward is observed. Reinforcement-learning agents update their values after each step, and so in this task they compute two prediction errors (<code>pe_1</code> and <code>pe_2</code>).
#
# For the first prediction error, after the spaceship choice, the immediate reward is zero ($r=0$). After all, no reward is observed after this choice. However, there is some estimate of _future_ reward as given by the estimated reward probability of the encountered alien.
#
# For the second prediction error, the reward is identical to whatever was observed (either 1 or 0, depending on what the alien delivers). Here, because there are no more future states in the trial, the estimate of future reward (<code>Q_prime</code>) is zero.
#
# In short: the updates happening in the task are actually not that complex (it's true!), both of them effectively contain two terms. You need to keep this in mind when you complete the script below. Among other things, you will write code that computes prediction errors for each trial, and use these in your temporal difference update function (<code>td_rule</code>).
#
# We realize it is a little bit counterintuitive to think that the agent _chooses_ an alien after transitioning to the planet. After all, there is only one alien per second-stage state (planet). However, it is important for the model to compute two separate prediction errors, for reasons we will see in the next second part of the workshop.

# %% [markdown]
# #### Some extensions of reinforcement-learning that we will not be considering here
#
# In reinforcement learning, prediction errors on a trial are important not just for the current trial and action, but they are actually used to update all previous actions too. Often, computational models attenuate the degree to which prior actions are updated by the current prediction with a 'eligbility trace decay' parameter $\lambda$ (lambda) (between 0 and 1). (There's no need to remember this term now). In short, the longer ago an action took place, the less it is affected by the current prediction error (it is discounted by $\lambda^t$, with _t_ the number of steps ago).
#
# Computer scientists also often discount expected future reward with the use of a discounting parameter $\gamma$ (gamma). That is, when computing the prediction error, they multiply the expectation of future reward by this parameter. From a psychologists perspective, this makes a lot of sense! We know that humans engage in temporal discounting.
#
# Today, however, we will keep things simple, and we will not either $\gamma$ or $\lambda$. We will not discount the expectation of future reward, and all actions that happened before the prediction error was computed will be updated in the same way. (So, on each trial this means that after the first prediction error one action value is updated, and after the second two prediction errors are updated.)
#
# If you are interested in learning more about this, you can read a nice short explanation of all these concepts here: https://medium.com/@violante.andre/simple-reinforcement-learning-temporal-difference-learning-e883ea0d65b0

# %% [markdown]
# ### Step 3. Simulating model-free behavior on the two-step task
# We finally know enough now to start building our simulation of the model-free agent! Hurray!
#
# In the section below, you can use your knowledge about the temporal difference updating rule and the softmax function to complete the model-free agent's code. The final code will simulate behaviour of a model-free agent on the task, which we can then plot afterwards and compare to our plots above.
#
# Several lines of code are already complete, but there are many (very important) lines of code for you to finish. Whenever we expect you to finish a line of code, we will make this explicitly clear with a commented bit of text (e.g., # complete this line). The comments also provide some hints, or tell you what different lines of codes do.
#
# You can use this image to help you understand how to fill out values for the model below:
#
# ![Task_structure](../Figures/task_structure_MFMB.png)
#
# Some things to keep in mind:
# - You will need to use the softmax function
# - You will need to use the temporal difference updating rule
# - You should think about how a model-free learner updates the values of each spaceship in the first-stage (what are r, Q_chosen and the prediction error?)
# - You should think about how it updates the values of each alien (what are r, Q_chosen, and the prediction error?)
#
# <mark>Finish the code below! Try to stick with it, even if it doesn't work out immediately.</mark>
#
# **Hint**: Where you need to complete a line we have left this comment:
# _#--- Fill this in_

# %% [markdown]
# # Model_free_agent function

# %%
# we will use a for loop, and generate choices for the agent as they go through the trials and learn from rewards
random.seed(2) # fixing the random seed so we can generate similar values

def model_free_agent(n_trials, alpha, beta):
    
    # we can set the same random seed so we get the same random values
    random.seed(2)
    
    # We'll use your generate_rewards function to generate drifting reward probabilities
    bounds = [0, 1]
    init_vals = [0.4, 0.6]
    drift_rate = 0.2
    reward_probs = generate_rewards(n_trials, bounds, init_vals, drift_rate)
        
    # Pre-allocate empty arrays for storing data
    prev_rews = np.zeros(n_trials) # This will store the rewards won on the previous trial
    first_stage_state = np.zeros(n_trials) # ... which spaceship pair the participants saw (0 or 1)
    state_sim = np.zeros(n_trials) # ... whether participants saw the same spaceship pair as on the previous trial, or the other one 
    choices = np.zeros(n_trials) # ... which spaceship the participants chose
    second_stage_state = np.zeros(n_trials) # ... which planet the participants transitioned to
    stay = np.zeros(n_trials) # ... whether participants visited the same planet as on the previous trial
    rewards = np.zeros(n_trials) # ... how many rewards the participants won on this trial

    # We initialise model-free values for the spaceships (all 0.5)
    Qmf1 = np.zeros((2,2)) + 0.5 # this will create an array inside an array (4 values, you can print them below to see)
    
    # and for the planets
    Qmf2 = np.full(2, 0.5)
    
    # Now, we loop through the trials, making choices, observing outcomes, and updating action values
    for i, reward_prob in enumerate(reward_probs): # for each iteration of this loop, the current trial is indexed by i

        # We randomly start with spaceship pair 1 (0) or pair 2 (1)
        s1 = np.random.choice([0, 1])
        
        # Compute the action probabilities for both spaceships (left: 0, right: 1). The Q-values of the current first-stage state are stored in Qmf1[s1]
        p = softmax(Qmf1[s1], beta) #--- Fill this in (beta??)

        # Make a 'weighted' choice using the np.random.uniform function and the variable p (you can use help(function) 
        # to find out more). In other words, choose the left spaceship (choice==0) with probability p[0] 
        # and the right (choice==1) with probability p[1]
        # You will need to write your code inside the brackets of the int() function, because otherwise Python will complain.
        choice = int(np.random.uniform(0,1) > p[0])                                  #--- Fill this in
        
        # Make the transition to the planet. Take a look at the diagram above. Think about which choices go which second-stage states.
        # This line of code should be _very_ simple.
        s2 = choice                                      #--- Fill this in

        # Calculate the first prediction error (no reward here (r==0), why?). The value of the chosen first-stage state is stored in Qmf1[s1,choice].
        # value in second state minus the value of the first state predicted
        pe_1 = Qmf2[s2] - Qmf1[s1,choice]       #--- Fill this in
        
        # Update the Q-value of the chosen spaceship in the starting state
        # update values = td rule
        Qmf1[s1,choice] = td_rule(alpha, Qmf1[s1,choice], pe_1)                         #--- Fill this in
        
        # Use np.random.uniform to determine whether the agent receives a reward (1 or 0, depending on the reward probability).
        # Note that you will have to use i and s2 to retrieve the current reward probability.
        # Again, You will need to write your code inside the brackets of the int() function.
        r =   int(np.random.uniform(0,1) < reward_probs[i,s2])                                     #--- Fill this in
        
        # Calculate the second prediction error. Again, note that there is a reward value here, but no future reward.
        pe_2 = r - Qmf2[s2]                                    #--- Fill this in
        
        # Update the Q-value of the visited alien (stored in Qmf2) using pe_2
        Qmf2[s2] =  td_rule(alpha, Qmf2[s2], pe_2)                               #--- Fill this in
        
        # Use pe_2 to also update the Q-value of the chosen spaceship in the starting state
        Qmf1[s1,choice] =  td_rule(alpha, Qmf1[s1,choice],pe_2)                        #--- Fill this in

        
        # save data from this trial to our pre-allocated arrays
        rewards[i] = r
        first_stage_state[i] = s1 # we log these so we can check the state similarity
        second_stage_state[i] = s2 # we log these so we can check if participants 'stayed' or 'switched'
        
        # these are based on the previous trial (i-1)
        if i != 0: # start at second trial (first trial this is set to 0)
            # whether they transitioned to the same planet on this trial
            if s2 == second_stage_state[i-1]:
                stay[i] = 1
            # whether they saw the same spaceship pair on this trial
            if s1 == first_stage_state[i-1]:
                state_sim[i] = 1
            # whether they received a reward on the previous trial
            prev_rews[i] = rewards[i-1]
        
        # you can uncomment the lines below to see what happens each trial in printed form.
        # note that if you uncomment these, the figure in the cell below will print all the way 
        # at the bottom of the printed statements (just comment the lines out again to see figure immediately)
        
#         ###  comment code between this this out or in (shortcut = ctrl + /)
        
#        # print spaceship choice and which pair was seen 
#        # spaceship chosen
#         if choice == 0:
#             position = 'left'
#         else:
#             position = 'right'
            
#         print(f'trial: {i+1}, spaceship pair: {s1+1}, spaceship chosen: {position}')
              
#         # print which planet was transitioned to
#         if s2 == 0:
#             color = 'red'
#         else:
#             color = 'purple'

#         print(f'transitioned to {color} planet, first prediction error: {pe_1}')
#         print(f'stay: {bool(stay[i])}, agent received: {r}')
#         print(f'{color} planet prediction error: {pe_2}')
#         print(f'Model-free q-values for all spaceships:\n[1:left, 1:right,\n2:left, 2:right]\n{Qmf1}')
#         print(f'Model-free q-values for planets [red, purple]: {Qmf2}\n')
        
#          ###  comment code between this out or in

        
    # data returned by function
    return stay, state_sim, prev_rews, rewards

# %% [markdown]
# #### Testing the model-free learner
#
# In the cell below, you can run the model-free function that you are writing, and you can see if it runs without any errors. If you do run into errors, try to see if you can decipher what might be going wrong from the outputs (and Google).
#
# Note that the code running without any errors does not mean that your code is doing what you _want_ it do. Your code does not know your intentions, and will blissfully execute your commands. There are many ways in which you can write wrong code, without this notebook giving you an error message.
#
# To debug your code, try printing the different choices that the simulated agent makes, and the Q-values for each choice. Are they updating as expected? At the end of the function above, we have provide useful print statements that we commented out. You can uncomment these, and use them to view the output of each trial consecutively to see how things change.
#
# Note that you will need to rerun the cell above after any change you make before the code below reflects these changes.

# %%
# initialise values
n_trials = 200
alpha = 0.5
beta = 4
    
# run an agent
[stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)
# Out:
# trial: 1, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: 0.0
# stay: False, agent received: 0
# red planet prediction error: -0.5
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.5  0.5 ]
#  [0.25 0.5 ]]
# Model-free q-values for planets [red, purple]: [0.25 0.5 ]
#
# trial: 2, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0
# stay: False, agent received: 0
# purple planet prediction error: -0.5
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.5  0.5 ]
#  [0.25 0.25]]
# Model-free q-values for planets [red, purple]: [0.25 0.25]
#
# trial: 3, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.25
# stay: True, agent received: 1
# purple planet prediction error: 0.75
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.5  0.75]
#  [0.25 0.25]]
# Model-free q-values for planets [red, purple]: [0.25  0.625]
#
# trial: 4, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.375
# stay: True, agent received: 1
# purple planet prediction error: 0.375
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.5   0.75 ]
#  [0.25  0.625]]
# Model-free q-values for planets [red, purple]: [0.25   0.8125]
#
# trial: 5, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.25
# stay: False, agent received: 0
# red planet prediction error: -0.25
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.25  0.75 ]
#  [0.25  0.625]]
# Model-free q-values for planets [red, purple]: [0.125  0.8125]
#
# trial: 6, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.125
# stay: True, agent received: 0
# red planet prediction error: -0.125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125 0.75 ]
#  [0.25  0.625]]
# Model-free q-values for planets [red, purple]: [0.0625 0.8125]
#
# trial: 7, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.1875
# stay: False, agent received: 1
# purple planet prediction error: 0.1875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125  0.75  ]
#  [0.25   0.8125]]
# Model-free q-values for planets [red, purple]: [0.0625  0.90625]
#
# trial: 8, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.15625
# stay: True, agent received: 1
# purple planet prediction error: 0.09375
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125  0.875 ]
#  [0.25   0.8125]]
# Model-free q-values for planets [red, purple]: [0.0625   0.953125]
#
# trial: 9, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.078125
# stay: True, agent received: 1
# purple planet prediction error: 0.046875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125  0.9375]
#  [0.25   0.8125]]
# Model-free q-values for planets [red, purple]: [0.0625    0.9765625]
#
# trial: 10, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0390625
# stay: True, agent received: 0
# purple planet prediction error: -0.9765625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125   0.46875]
#  [0.25    0.8125 ]]
# Model-free q-values for planets [red, purple]: [0.0625     0.48828125]
#
# trial: 11, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.32421875
# stay: True, agent received: 1
# purple planet prediction error: 0.51171875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125   0.46875]
#  [0.25    0.90625]]
# Model-free q-values for planets [red, purple]: [0.0625     0.74414062]
#
# trial: 12, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.162109375
# stay: True, agent received: 0
# purple planet prediction error: -0.744140625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125    0.46875 ]
#  [0.25     0.453125]]
# Model-free q-values for planets [red, purple]: [0.0625     0.37207031]
#
# trial: 13, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0966796875
# stay: True, agent received: 1
# purple planet prediction error: 0.6279296875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125    0.734375]
#  [0.25     0.453125]]
# Model-free q-values for planets [red, purple]: [0.0625     0.68603516]
#
# trial: 14, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.1875
# stay: False, agent received: 1
# red planet prediction error: 0.9375
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125    0.734375]
#  [0.625    0.453125]]
# Model-free q-values for planets [red, purple]: [0.53125    0.68603516]
#
# trial: 15, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.09375
# stay: True, agent received: 0
# red planet prediction error: -0.53125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125    0.734375]
#  [0.3125   0.453125]]
# Model-free q-values for planets [red, purple]: [0.265625   0.68603516]
#
# trial: 16, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.04833984375
# stay: False, agent received: 1
# purple planet prediction error: 0.31396484375
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125     0.8671875]
#  [0.3125    0.453125 ]]
# Model-free q-values for planets [red, purple]: [0.265625   0.84301758]
#
# trial: 17, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.024169921875
# stay: True, agent received: 1
# purple planet prediction error: 0.156982421875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.93359375]
#  [0.3125     0.453125  ]]
# Model-free q-values for planets [red, purple]: [0.265625   0.92150879]
#
# trial: 18, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.4683837890625
# stay: True, agent received: 0
# purple planet prediction error: -0.9215087890625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.93359375]
#  [0.3125     0.2265625 ]]
# Model-free q-values for planets [red, purple]: [0.265625   0.46075439]
#
# trial: 19, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.046875
# stay: False, agent received: 0
# red planet prediction error: -0.265625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.93359375]
#  [0.15625    0.2265625 ]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.46075439]
#
# trial: 20, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.23419189453125
# stay: False, agent received: 1
# purple planet prediction error: 0.53924560546875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.93359375]
#  [0.15625    0.61328125]]
# Model-free q-values for planets [red, purple]: [0.1328125 0.7303772]
#
# trial: 21, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.203216552734375
# stay: True, agent received: 1
# purple planet prediction error: 0.269622802734375
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.96679688]
#  [0.15625    0.61328125]]
# Model-free q-values for planets [red, purple]: [0.1328125 0.8651886]
#
# trial: 22, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.1016082763671875
# stay: True, agent received: 1
# purple planet prediction error: 0.1348114013671875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.98339844]
#  [0.15625    0.61328125]]
# Model-free q-values for planets [red, purple]: [0.1328125 0.9325943]
#
# trial: 23, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.31931304931640625
# stay: True, agent received: 0
# purple planet prediction error: -0.9325942993164062
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.98339844]
#  [0.15625    0.30664062]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.46629715]
#
# trial: 24, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.15965652465820312
# stay: True, agent received: 0
# purple planet prediction error: -0.4662971496582031
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.98339844]
#  [0.15625    0.15332031]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.23314857]
#
# trial: 25, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.07982826232910156
# stay: True, agent received: 1
# purple planet prediction error: 0.7668514251708984
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.98339844]
#  [0.15625    0.57666016]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.61657429]
#
# trial: 26, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.3668241500854492
# stay: True, agent received: 1
# purple planet prediction error: 0.3834257125854492
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.99169922]
#  [0.15625    0.57666016]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.80828714]
#
# trial: 27, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.2316269874572754
# stay: True, agent received: 1
# purple planet prediction error: 0.1917128562927246
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.99169922]
#  [0.15625    0.78833008]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.90414357]
#
# trial: 28, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.1158134937286377
# stay: True, agent received: 0
# purple planet prediction error: -0.9041435718536377
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.99169922]
#  [0.15625    0.39416504]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.45207179]
#
# trial: 29, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.05790674686431885
# stay: True, agent received: 0
# purple planet prediction error: -0.45207178592681885
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.99169922]
#  [0.15625    0.19708252]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.22603589]
#
# trial: 30, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.028953373432159424
# stay: True, agent received: 0
# purple planet prediction error: -0.22603589296340942
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.99169922]
#  [0.15625    0.09854126]]
# Model-free q-values for planets [red, purple]: [0.1328125  0.11301795]
#
# trial: 31, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.0234375
# stay: False, agent received: 0
# red planet prediction error: -0.1328125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.125      0.99169922]
#  [0.078125   0.09854126]]
# Model-free q-values for planets [red, purple]: [0.06640625 0.11301795]
#
# trial: 32, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.05859375
# stay: True, agent received: 0
# red planet prediction error: -0.06640625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.0625     0.99169922]
#  [0.078125   0.09854126]]
# Model-free q-values for planets [red, purple]: [0.03320312 0.11301795]
#
# trial: 33, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.8786812722682953
# stay: False, agent received: 1
# purple planet prediction error: 0.8869820535182953
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.0625     0.99584961]
#  [0.078125   0.09854126]]
# Model-free q-values for planets [red, purple]: [0.03320312 0.55650897]
#
# trial: 34, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.43934063613414764
# stay: True, agent received: 0
# purple planet prediction error: -0.5565089732408524
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.0625     0.4979248 ]
#  [0.078125   0.09854126]]
# Model-free q-values for planets [red, purple]: [0.03320312 0.27825449]
#
# trial: 35, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.029296875
# stay: False, agent received: 0
# red planet prediction error: -0.033203125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.4979248 ]
#  [0.078125   0.09854126]]
# Model-free q-values for planets [red, purple]: [0.01660156 0.27825449]
#
# trial: 36, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.0615234375
# stay: True, agent received: 0
# red planet prediction error: -0.0166015625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.4979248 ]
#  [0.0390625  0.09854126]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.27825449]
#
# trial: 37, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.17971322685480118
# stay: False, agent received: 0
# purple planet prediction error: -0.2782544866204262
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.4979248 ]
#  [0.0390625  0.04927063]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.13912724]
#
# trial: 38, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.08985661342740059
# stay: True, agent received: 1
# purple planet prediction error: 0.8608727566897869
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.4979248 ]
#  [0.0390625  0.52463531]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.56956362]
#
# trial: 39, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.044928306713700294
# stay: True, agent received: 1
# purple planet prediction error: 0.43043637834489346
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.4979248 ]
#  [0.0390625  0.76231766]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.78478181]
#
# trial: 40, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.2868570061400533
# stay: True, agent received: 0
# purple planet prediction error: -0.7847818108275533
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.2489624 ]
#  [0.0390625  0.76231766]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.39239091]
#
# trial: 41, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.14342850307002664
# stay: True, agent received: 0
# purple planet prediction error: -0.39239090541377664
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.1244812 ]
#  [0.0390625  0.76231766]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.19619545]
#
# trial: 42, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.5661222047638148
# stay: True, agent received: 0
# purple planet prediction error: -0.19619545270688832
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.1244812 ]
#  [0.0390625  0.38115883]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.09809773]
#
# trial: 43, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.2830611023819074
# stay: True, agent received: 1
# purple planet prediction error: 0.9019022736465558
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.03125    0.1244812 ]
#  [0.0390625  0.69057941]]
# Model-free q-values for planets [red, purple]: [0.00830078 0.54904886]
#
# trial: 44, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.02294921875
# stay: False, agent received: 0
# red planet prediction error: -0.00830078125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.015625   0.1244812 ]
#  [0.0390625  0.69057941]]
# Model-free q-values for planets [red, purple]: [0.00415039 0.54904886]
#
# trial: 45, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.1415305511909537
# stay: False, agent received: 0
# purple planet prediction error: -0.5490488631767221
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.015625   0.1244812 ]
#  [0.0390625  0.34528971]]
# Model-free q-values for planets [red, purple]: [0.00415039 0.27452443]
#
# trial: 46, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.07076527559547685
# stay: True, agent received: 1
# purple planet prediction error: 0.725475568411639
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.015625   0.1244812 ]
#  [0.0390625  0.67264485]]
# Model-free q-values for planets [red, purple]: [0.00415039 0.63726222]
#
# trial: 47, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.5127810146223055
# stay: True, agent received: 1
# purple planet prediction error: 0.3627377842058195
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.015625   0.5622406 ]
#  [0.0390625  0.67264485]]
# Model-free q-values for planets [red, purple]: [0.00415039 0.81863111]
#
# trial: 48, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.14598625430517131
# stay: True, agent received: 1
# purple planet prediction error: 0.18136889210290974
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.015625   0.5622406 ]
#  [0.0390625  0.83632243]]
# Model-free q-values for planets [red, purple]: [0.00415039 0.90931555]
#
# trial: 49, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.011474609375
# stay: False, agent received: 1
# red planet prediction error: 0.995849609375
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.5078125  0.5622406 ]
#  [0.0390625  0.83632243]]
# Model-free q-values for planets [red, purple]: [0.5020752  0.90931555]
#
# trial: 50, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.0057373046875
# stay: True, agent received: 1
# red planet prediction error: 0.4979248046875
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.75390625 0.5622406 ]
#  [0.0390625  0.83632243]]
# Model-free q-values for planets [red, purple]: [0.7510376  0.90931555]
#
# trial: 51, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.00286865234375
# stay: True, agent received: 0
# red planet prediction error: -0.75103759765625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37695312 0.5622406 ]
#  [0.0390625  0.83632243]]
# Model-free q-values for planets [red, purple]: [0.3755188  0.90931555]
#
# trial: 52, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.07299312715258566
# stay: False, agent received: 0
# purple planet prediction error: -0.9093155539485451
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37695312 0.5622406 ]
#  [0.0390625  0.41816121]]
# Model-free q-values for planets [red, purple]: [0.3755188  0.45465778]
#
# trial: 53, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.03649656357629283
# stay: True, agent received: 1
# purple planet prediction error: 0.5453422230257274
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37695312 0.5622406 ]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.3755188  0.72732889]
#
# trial: 54, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.16508828790119878
# stay: True, agent received: 0
# purple planet prediction error: -0.7273288884871363
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37695312 0.2811203 ]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.3755188  0.36366444]
#
# trial: 55, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.001434326171875
# stay: False, agent received: 0
# red planet prediction error: -0.375518798828125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18847656 0.2811203 ]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.1877594  0.36366444]
#
# trial: 56, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.08254414395059939
# stay: False, agent received: 0
# purple planet prediction error: -0.36366444424356814
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18847656 0.14056015]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.1877594  0.18183222]
#
# trial: 57, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.041272071975299696
# stay: True, agent received: 1
# purple planet prediction error: 0.8181677778782159
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18847656 0.57028008]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.1877594  0.59091611]
#
# trial: 58, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.020636035987649848
# stay: True, agent received: 1
# purple planet prediction error: 0.40908388893910796
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18847656 0.78514004]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.1877594  0.79545806]
#
# trial: 59, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.010318017993824924
# stay: True, agent received: 0
# purple planet prediction error: -0.795458055530446
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18847656 0.39257002]
#  [0.0390625  0.70908061]]
# Model-free q-values for planets [red, purple]: [0.1877594  0.39772903]
#
# trial: 60, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.31135157893376686
# stay: True, agent received: 0
# purple planet prediction error: -0.397729027765223
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18847656 0.39257002]
#  [0.0390625  0.3545403 ]]
# Model-free q-values for planets [red, purple]: [0.1877594  0.19886451]
#
# trial: 61, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.0007171630859375
# stay: False, agent received: 0
# red planet prediction error: -0.1877593994140625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.09423828 0.39257002]
#  [0.0390625  0.3545403 ]]
# Model-free q-values for planets [red, purple]: [0.0938797  0.19886451]
#
# trial: 62, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.15567578946688343
# stay: False, agent received: 1
# purple planet prediction error: 0.8011354861173885
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.09423828 0.39257002]
#  [0.0390625  0.67727015]]
# Model-free q-values for planets [red, purple]: [0.0938797  0.59943226]
#
# trial: 63, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.00035858154296875
# stay: False, agent received: 0
# red planet prediction error: -0.09387969970703125
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.04711914 0.39257002]
#  [0.0390625  0.67727015]]
# Model-free q-values for planets [red, purple]: [0.04693985 0.59943226]
#
# trial: 64, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.07783789473344171
# stay: False, agent received: 0
# purple planet prediction error: -0.5994322569413058
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.04711914 0.39257002]
#  [0.0390625  0.33863508]]
# Model-free q-values for planets [red, purple]: [0.04693985 0.29971613]
#
# trial: 65, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.000179290771484375
# stay: False, agent received: 0
# red planet prediction error: -0.046939849853515625
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.02355957 0.39257002]
#  [0.0390625  0.33863508]]
# Model-free q-values for planets [red, purple]: [0.02346992 0.29971613]
#
# trial: 66, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -8.96453857421875e-05
# stay: True, agent received: 1
# red planet prediction error: 0.9765300750732422
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.51177979 0.39257002]
#  [0.0390625  0.33863508]]
# Model-free q-values for planets [red, purple]: [0.51173496 0.29971613]
#
# trial: 67, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -4.482269287109375e-05
# stay: True, agent received: 1
# red planet prediction error: 0.4882650375366211
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.75588989 0.39257002]
#  [0.0390625  0.33863508]]
# Model-free q-values for planets [red, purple]: [0.75586748 0.29971613]
#
# trial: 68, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.09285389029765767
# stay: False, agent received: 1
# purple planet prediction error: 0.7002838715293471
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.75588989 0.69628501]
#  [0.0390625  0.33863508]]
# Model-free q-values for planets [red, purple]: [0.75586748 0.64985806]
#
# trial: 69, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -2.2411346435546875e-05
# stay: False, agent received: 0
# red planet prediction error: -0.7558674812316895
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.69628501]
#  [0.0390625  0.33863508]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.64985806]
#
# trial: 70, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.3112229883979527
# stay: False, agent received: 1
# purple planet prediction error: 0.35014193576467356
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.69628501]
#  [0.0390625  0.66931754]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.82492903]
#
# trial: 71, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.12864402273350795
# stay: True, agent received: 1
# purple planet prediction error: 0.17507096788233678
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.8481425 ]
#  [0.0390625  0.66931754]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.91246452]
#
# trial: 72, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.06432201136675397
# stay: True, agent received: 0
# purple planet prediction error: -0.9124645160588316
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.42407125]
#  [0.0390625  0.66931754]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.45623226]
#
# trial: 73, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.21308527988927106
# stay: True, agent received: 1
# purple planet prediction error: 0.5437677419705842
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.42407125]
#  [0.0390625  0.83465877]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.72811613]
#
# trial: 74, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.3040448766686691
# stay: True, agent received: 0
# purple planet prediction error: -0.7281161290147079
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.21203563]
#  [0.0390625  0.83465877]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.36405806]
#
# trial: 75, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.4706007044519895
# stay: True, agent received: 1
# purple planet prediction error: 0.6359419354926461
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.21203563]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.68202903]
#
# trial: 76, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.4699934060806577
# stay: True, agent received: 1
# purple planet prediction error: 0.31797096774632294
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.60601781]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.84101452]
#
# trial: 77, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.23499670304032882
# stay: True, agent received: 0
# purple planet prediction error: -0.8410145161268385
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.37794495 0.30300891]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.37793374 0.42050726]
#
# trial: 78, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -1.1205673217773438e-05
# stay: False, agent received: 0
# red planet prediction error: -0.3779337406158447
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18897247 0.30300891]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.18896687 0.42050726]
#
# trial: 79, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.11749835152016441
# stay: False, agent received: 1
# purple planet prediction error: 0.5794927419365807
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18897247 0.65150445]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.18896687 0.71025363]
#
# trial: 80, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.058749175760082206
# stay: True, agent received: 0
# purple planet prediction error: -0.7102536290317096
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.18897247 0.32575223]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.18896687 0.35512681]
#
# trial: 81, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -5.602836608886719e-06
# stay: False, agent received: 0
# red planet prediction error: -0.18896687030792236
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.09448624 0.32575223]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.09448344 0.35512681]
#
# trial: 82, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -2.8014183044433594e-06
# stay: True, agent received: 1
# red planet prediction error: 0.9055165648460388
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.54724312 0.32575223]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.54724172 0.35512681]
#
# trial: 83, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -1.4007091522216797e-06
# stay: True, agent received: 1
# red planet prediction error: 0.4527582824230194
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.77362156 0.32575223]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.77362086 0.35512681]
#
# trial: 84, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -7.003545761108398e-07
# stay: True, agent received: 1
# red planet prediction error: 0.2263791412115097
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.32575223]
#  [0.0390625  0.91732938]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.35512681]
#
# trial: 85, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.5622025699638169
# stay: False, agent received: 1
# purple planet prediction error: 0.6448731854841452
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.32575223]
#  [0.0390625  0.95866469]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.67756341]
#
# trial: 86, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.28110128498190845
# stay: True, agent received: 1
# purple planet prediction error: 0.3224365927420726
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.32575223]
#  [0.0390625  0.97933235]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.8387817 ]
#
# trial: 87, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.14055064249095417
# stay: True, agent received: 1
# purple planet prediction error: 0.16121829637103624
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.32575223]
#  [0.0390625  0.98966617]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.91939085]
#
# trial: 88, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.5936386251786682
# stay: True, agent received: 1
# purple planet prediction error: 0.08060914818551812
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.66287611]
#  [0.0390625  0.98966617]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.95969543]
#
# trial: 89, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.02997074715271797
# stay: True, agent received: 1
# purple planet prediction error: 0.040304574092759005
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.66287611]
#  [0.0390625  0.99483309]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.97984771]
#
# trial: 90, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.014985373576358985
# stay: True, agent received: 1
# purple planet prediction error: 0.020152287046379502
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.66287611]
#  [0.0390625  0.99741654]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.98992386]
#
# trial: 91, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.3270477431589034
# stay: True, agent received: 1
# purple planet prediction error: 0.010076143523189751
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.83143806]
#  [0.0390625  0.99741654]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.99496193]
#
# trial: 92, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0024546150265846167
# stay: True, agent received: 1
# purple planet prediction error: 0.005038071761594876
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.88681078 0.83143806]
#  [0.0390625  0.99870827]]
# Model-free q-values for planets [red, purple]: [0.88681043 0.99748096]
#
# trial: 93, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -3.501772880554199e-07
# stay: False, agent received: 0
# red planet prediction error: -0.8868104293942451
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.83143806]
#  [0.0390625  0.99870827]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.99748096]
#
# trial: 94, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0012273075132922528
# stay: False, agent received: 1
# purple planet prediction error: 0.0025190358807973823
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.83143806]
#  [0.0390625  0.99935414]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.99874048]
#
# trial: 95, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0006136537566461264
# stay: True, agent received: 1
# purple planet prediction error: 0.0012595179403986911
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.83143806]
#  [0.0390625  0.99967707]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.99937024]
#
# trial: 96, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0003068268783230632
# stay: True, agent received: 1
# purple planet prediction error: 0.0006297589701993456
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.83143806]
#  [0.0390625  0.99983853]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.99968512]
#
# trial: 97, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0001534134391615316
# stay: True, agent received: 1
# purple planet prediction error: 0.0003148794850996728
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.83143806]
#  [0.0390625  0.99991927]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.99984256]
#
# trial: 98, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -7.670671958082131e-05
# stay: True, agent received: 1
# purple planet prediction error: 0.0001574397425498919
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.83143806]
#  [0.0390625  0.99995963]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.99992128]
#
# trial: 99, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.16848322346977163
# stay: True, agent received: 0
# purple planet prediction error: -0.999921280128725
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.41571903]
#  [0.0390625  0.99995963]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.49996064]
#
# trial: 100, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.49999899342415294
# stay: True, agent received: 1
# purple planet prediction error: 0.5000393599356374
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.41571903]
#  [0.0390625  0.99997982]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.74998032]
#
# trial: 101, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.3342612917027045
# stay: True, agent received: 1
# purple planet prediction error: 0.2500196799678187
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.70785951]
#  [0.0390625  0.99997982]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.87499016]
#
# trial: 102, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.1671306458513523
# stay: True, agent received: 1
# purple planet prediction error: 0.12500983998390935
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.85392976]
#  [0.0390625  0.99997982]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.93749508]
#
# trial: 103, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.062484736736212465
# stay: True, agent received: 0
# purple planet prediction error: -0.9374950800080453
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.85392976]
#  [0.0390625  0.49998991]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.46874754]
#
# trial: 104, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.38518221707834654
# stay: True, agent received: 1
# purple planet prediction error: 0.5312524599959774
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.92696488]
#  [0.0390625  0.49998991]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.73437377]
#
# trial: 105, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.19259110853917327
# stay: True, agent received: 1
# purple planet prediction error: 0.2656262299979887
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.96348244]
#  [0.0390625  0.49998991]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.86718689]
#
# trial: 106, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.36719697662887674
# stay: True, agent received: 0
# purple planet prediction error: -0.8671868850010056
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.44340539 0.96348244]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.44340521 0.43359344]
#
# trial: 107, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -1.7508864402770996e-07
# stay: False, agent received: 0
# red planet prediction error: -0.4434052146971226
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.22170269 0.96348244]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.22170261 0.43359344]
#
# trial: 108, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.5298889967700895
# stay: False, agent received: 0
# purple planet prediction error: -0.4335934425005028
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.22170269 0.48174122]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.22170261 0.21679672]
#
# trial: 109, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.26494449838504475
# stay: True, agent received: 1
# purple planet prediction error: 0.7832032787497486
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.22170269 0.74087061]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.22170261 0.60839836]
#
# trial: 110, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.13247224919252232
# stay: True, agent received: 0
# purple planet prediction error: -0.6083983606251258
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.22170269 0.3704353 ]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.22170261 0.30419918]
#
# trial: 111, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -8.754432201385498e-08
# stay: False, agent received: 0
# red planet prediction error: -0.2217026073485613
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.11085135 0.3704353 ]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.1108513  0.30419918]
#
# trial: 112, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.06623612459626116
# stay: False, agent received: 0
# purple planet prediction error: -0.3041991803125629
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.11085135 0.18521765]
#  [0.0390625  0.24999495]]
# Model-free q-values for planets [red, purple]: [0.1108513  0.15209959]
#
# trial: 113, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.097895364029783
# stay: True, agent received: 1
# purple planet prediction error: 0.8479004098437186
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.11085135 0.18521765]
#  [0.0390625  0.62499748]]
# Model-free q-values for planets [red, purple]: [0.1108513 0.5760498]
#
# trial: 114, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.048947682014891525
# stay: True, agent received: 0
# purple planet prediction error: -0.5760497950781407
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.11085135 0.18521765]
#  [0.0390625  0.31249874]]
# Model-free q-values for planets [red, purple]: [0.1108513 0.2880249]
#
# trial: 115, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.024473841007445762
# stay: True, agent received: 1
# purple planet prediction error: 0.7119751024609297
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.11085135 0.18521765]
#  [0.0390625  0.65624937]]
# Model-free q-values for planets [red, purple]: [0.1108513  0.64401245]
#
# trial: 116, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -4.377216100692749e-08
# stay: False, agent received: 0
# red planet prediction error: -0.11085130367428064
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.05542567 0.18521765]
#  [0.0390625  0.65624937]]
# Model-free q-values for planets [red, purple]: [0.05542565 0.64401245]
#
# trial: 117, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.012236920503722937
# stay: False, agent received: 1
# purple planet prediction error: 0.3559875512304649
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.05542567 0.18521765]
#  [0.0390625  0.82812468]]
# Model-free q-values for planets [red, purple]: [0.05542565 0.82200622]
#
# trial: 118, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -2.1886080503463745e-08
# stay: False, agent received: 1
# red planet prediction error: 0.9445743481628597
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.52771284 0.18521765]
#  [0.0390625  0.82812468]]
# Model-free q-values for planets [red, purple]: [0.52771283 0.82200622]
#
# trial: 119, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.6367885719303555
# stay: False, agent received: 0
# purple planet prediction error: -0.8220062243847676
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.52771284 0.09260883]
#  [0.0390625  0.82812468]]
# Model-free q-values for planets [red, purple]: [0.52771283 0.41100311]
#
# trial: 120, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: -1.0943040251731873e-08
# stay: False, agent received: 0
# red planet prediction error: -0.5277128259185702
# ...
# stay: True, agent received: 1
# purple planet prediction error: 0.0018769487712990696
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.98805378]
#  [0.00976562 0.94313681]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99061526e-01]
#
# trial: 163, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.011007744351743232
# stay: True, agent received: 1
# purple planet prediction error: 0.0009384743856495348
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99402689]
#  [0.00976562 0.94313681]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99530763e-01]
#
# trial: 164, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.05639395155317262
# stay: True, agent received: 1
# purple planet prediction error: 0.0004692371928247674
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99402689]
#  [0.00976562 0.97156841]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99765381e-01]
#
# trial: 165, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.02819697577658631
# stay: True, agent received: 1
# purple planet prediction error: 0.0002346185964123837
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99402689]
#  [0.00976562 0.9857842 ]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99882691e-01]
#
# trial: 166, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.005855800070490136
# stay: True, agent received: 1
# purple planet prediction error: 0.00011730929820619185
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99701345]
#  [0.00976562 0.9857842 ]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99941345e-01]
#
# trial: 167, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0029279000352451234
# stay: True, agent received: 1
# purple planet prediction error: 5.865464910304041e-05
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99850672]
#  [0.00976562 0.9857842 ]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99970673e-01]
#
# trial: 168, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.014186469861947826
# stay: True, agent received: 1
# purple planet prediction error: 2.9327324551520206e-05
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99850672]
#  [0.00976562 0.9928921 ]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99985336e-01]
#
# trial: 169, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.007093234930973913
# stay: True, agent received: 1
# purple planet prediction error: 1.4663662275760103e-05
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99850672]
#  [0.00976562 0.99644605]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99992668e-01]
#
# trial: 170, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0014859455110362019
# stay: True, agent received: 1
# purple planet prediction error: 7.331831137880052e-06
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99925336]
#  [0.00976562 0.99644605]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99996334e-01]
#
# trial: 171, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0035502833810560075
# stay: True, agent received: 1
# purple planet prediction error: 3.6659155688845146e-06
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99925336]
#  [0.00976562 0.99822303]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99998167e-01]
#
# trial: 172, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0017751416905280593
# stay: True, agent received: 1
# purple planet prediction error: 1.8329577844422573e-06
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99925336]
#  [0.00976562 0.99911151]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99999084e-01]
#
# trial: 173, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0007457221921948198
# stay: True, agent received: 1
# purple planet prediction error: 9.164788922211287e-07
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99962668]
#  [0.00976562 0.99911151]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99999542e-01]
#
# trial: 174, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.0008880290847100847
# stay: True, agent received: 1
# purple planet prediction error: 4.582394461660755e-07
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.99962668]
#  [0.00976562 0.99955576]]
# Model-free q-values for planets [red, purple]: [5.15344557e-04 9.99999771e-01]
#
# trial: 175, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.00037309021582043744
# stay: True, agent received: 0
# purple planet prediction error: -0.9999997708802769
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.49981334]
#  [0.00976562 0.99955576]]
# Model-free q-values for planets [red, purple]: [0.00051534 0.49999989]
#
# trial: 176, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.49955587089778347
# stay: True, agent received: 0
# purple planet prediction error: -0.49999988544013846
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.49981334]
#  [0.00976562 0.49977788]]
# Model-free q-values for planets [red, purple]: [0.00051534 0.24999994]
#
# trial: 177, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.009250280443438896
# stay: False, agent received: 1
# red planet prediction error: 0.9994846554434389
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.49981334]
#  [0.50488281 0.49977788]]
# Model-free q-values for planets [red, purple]: [0.50025767 0.24999994]
#
# trial: 178, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.2497779354488918
# stay: False, agent received: 0
# purple planet prediction error: -0.24999994272006923
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.49981334]
#  [0.50488281 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.50025767 0.12499997]
#
# trial: 179, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.004625140221719448
# stay: False, agent received: 0
# red planet prediction error: -0.5002576722782806
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.49981334]
#  [0.25244141 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.25012884 0.12499997]
#
# trial: 180, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.002312570110859724
# stay: True, agent received: 1
# red planet prediction error: 0.7498711638608597
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.49981334]
#  [0.6262207  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.62506442 0.12499997]
#
# trial: 181, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.3748133689721936
# stay: False, agent received: 0
# purple planet prediction error: -0.12499997136003461
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.24990667]
#  [0.6262207  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.62506442 0.06249999]
#
# trial: 182, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.18740668448609676
# stay: True, agent received: 0
# purple planet prediction error: -0.06249998568001731
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.12495334]
#  [0.6262207  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.62506442 0.03124999]
#
# trial: 183, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.001156285055429862
# stay: False, agent received: 1
# red planet prediction error: 0.37493558193042986
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.12495334]
#  [0.81311035 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.81253221 0.03124999]
#
# trial: 184, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.09370334224304838
# stay: False, agent received: 0
# purple planet prediction error: -0.031249992840008654
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.06247667]
#  [0.81311035 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.81253221 0.015625  ]
#
# trial: 185, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.000578142527714931
# stay: False, agent received: 1
# red planet prediction error: 0.18746779096521493
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.06247667]
#  [0.90655518 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.9062661 0.015625 ]
#
# trial: 186, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.0002890712638574655
# stay: True, agent received: 1
# red planet prediction error: 0.09373389548260747
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.06247667]
#  [0.95327759 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.95313305 0.015625  ]
#
# trial: 187, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.00014453563192873276
# stay: True, agent received: 1
# red planet prediction error: 0.04686694774130373
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.06247667]
#  [0.97663879 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.97656653 0.015625  ]
#
# trial: 188, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.04685167112152419
# stay: False, agent received: 1
# purple planet prediction error: 0.9843750035799956
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00206138 0.53123833]
#  [0.97663879 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.97656653 0.5078125 ]
#
# trial: 189, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: 0.9745051478603575
# stay: False, agent received: 0
# red planet prediction error: -0.9765665261293481
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.53123833]
#  [0.97663879 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.48828326 0.5078125 ]
#
# trial: 190, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.023425835560762054
# stay: False, agent received: 0
# purple planet prediction error: -0.5078124982100022
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.26561917]
#  [0.97663879 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.48828326 0.25390625]
#
# trial: 191, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.48835553088063843
# stay: False, agent received: 0
# red planet prediction error: -0.48828326306467407
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.26561917]
#  [0.4883194  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.24414163 0.25390625]
#
# trial: 192, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.011712917780381082
# stay: False, agent received: 1
# purple planet prediction error: 0.746093750894999
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.63280958]
#  [0.4883194  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.24414163 0.62695312]
#
# trial: 193, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: -0.24417776544031922
# stay: False, agent received: 1
# red planet prediction error: 0.755858368467663
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.63280958]
#  [0.7441597  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.62207082 0.62695312]
#
# trial: 194, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.005856458890190486
# stay: False, agent received: 1
# purple planet prediction error: 0.37304687544749937
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.81640479]
#  [0.7441597  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.62207082 0.81347656]
#
# trial: 195, spaceship pair: 1, spaceship chosen: right
# transitioned to purple planet, first prediction error: -0.0029282294450951873
# stay: True, agent received: 1
# purple planet prediction error: 0.18652343772374969
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.00103069 0.9082024 ]
#  [0.7441597  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.62207082 0.90673828]
#
# trial: 196, spaceship pair: 1, spaceship chosen: left
# transitioned to red planet, first prediction error: 0.6210401266316732
# stay: False, agent received: 1
# red planet prediction error: 0.3779291842338315
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.50051534 0.9082024 ]
#  [0.7441597  0.24988894]]
# Model-free q-values for planets [red, purple]: [0.81103541 0.90673828]
#
# trial: 197, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: 0.06687570939675613
# stay: True, agent received: 1
# red planet prediction error: 0.18896459211691574
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.50051534 0.9082024 ]
#  [0.87207985 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.9055177  0.90673828]
#
# trial: 198, spaceship pair: 2, spaceship chosen: left
# transitioned to red planet, first prediction error: 0.03343785469837801
# stay: True, agent received: 0
# red planet prediction error: -0.9055177039415421
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.50051534 0.9082024 ]
#  [0.43603992 0.24988894]]
# Model-free q-values for planets [red, purple]: [0.45275885 0.90673828]
#
# trial: 199, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.6568493420536446
# stay: False, agent received: 0
# purple planet prediction error: -0.9067382811381252
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.50051534 0.9082024 ]
#  [0.43603992 0.12494447]]
# Model-free q-values for planets [red, purple]: [0.45275885 0.45336914]
#
# trial: 200, spaceship pair: 2, spaceship chosen: right
# transitioned to purple planet, first prediction error: 0.32842467102682227
# stay: True, agent received: 0
# purple planet prediction error: -0.4533691405690626
# Model-free q-values for all spaceships:
# [1:left, 1:right,
# 2:left, 2:right]
# [[0.50051534 0.9082024 ]
#  [0.43603992 0.06247223]]
# Model-free q-values for planets [red, purple]: [0.45275885 0.22668457]

# %% [markdown]
# You can run the code below to plot simulated behavior from your code.
#
# If you see errors, then it is most likely that you some mistakes in your code above. Read the error messages and try to assess what you need to change. If the code below produces a plot, this means that your code ran without throwing error. However, your code not crashing is not a good indication that it works _as intended_.
#
# Therefore, you should check whether your plot resembles that of a model-free learner (figure presented for reference below). If it does not, you will need to dig into your <code>model_free_agent</code> code. Often this is the hardest part. You will have to use critical reasoning skills, and experimentation to determine what goes wrong. You can use the commented out bits of code at the end of function to get more fine-grained insight into how actions are updated from trial to trial.
#
# If the plots look alike, a great way to test it a few more times is to increase the number of trials. This is because the more trials the agent completes the less "noisy" the plot will be. You will notice that the plots are quite variable with just 200 trials, but very stable with 20000.
#
# **Hint**: run the cell below a few times, to get a better feel of what kind of behavior we are generating!

# %%
# Run an agent and plot the data (Note: you can run this cell over and over again)
n_trials = 20000
alpha = 0.5
beta = 4

[stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)

# calculate group scores
df = pd.DataFrame({"Spaceship_State_Sim":state_sim,"Previous_Rewards":prev_rews,"Stay":stay})
plot_data = df.groupby(["Spaceship_State_Sim","Previous_Rewards"]).mean().unstack()
a = plot_data.reset_index()

# plot the graph
fig, ax = plt.subplots()
a.plot(x = "Spaceship_State_Sim", kind="bar", ylim = [0.5,0.9],
       stacked=False,ax=ax)

ax.legend(["Loss","Win"])
ax.set_ylabel("Stay Probability", size = 14)
plt.xticks(rotation=1)
ax.set_xticklabels(['Different','Same'])
ax.set_xlabel("Starting state: current vs previous", size = 14)
ax.invert_xaxis()
plt.title('Simulated model-free agent', size = 16)
plt.show()

# %% [markdown]
# #### Let's compare these to the model-free stay probabilities from before:
#
# ![MF_only](../Figures/Doll_MF_Only.png) <br>
#
# Does your model-free agent behave similarly to what is depicted in this plot? Can you identify the similarities in behaviour after winning or losing on a trial, depending on whether the starting state is the same as on the previous trial? Does your agent do the 'right' thing? (Note that the limits on the y-axes are different between these figures!)

# %% [markdown]
# ### Performance
#
# So, how well does the model-free agent perform this task? One way to quantify this is to calculate on what percentage of the trials the agent won a reward. The code below will compute this for you. How well does your model-free agent perform?
#
# Note that if your agent wins less than or roughly equal to 50% of all trials, it's not performing better than chance. (You would expect the same performance if we chose based on coin flips). Let's how well your agent did with <code>alpha = 0.5</code> and <code>beta = 4</code>. When we performed this analysis, and we let the model-free agent perform a ton of trials (say 20,000), the agent won on between 52.5% and 55% of all trials. Not great, but better than chance! If you agent does not score more than 50% most the time, there might be something wrong with your code.

# %%
# every time you run this cell, it will simulate a new agent with the settings below. You will see the percentage of trials, every time you will see a percentage

n_trials = 20000
alpha = 0.5
beta = 4

[stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)

# calculate and print performance
print(f'They won on: {sum(rewards)*100 / n_trials}% of the trials')
# Out:
# They won on: 52.985% of the trials

# %% [markdown]
# # A decision for you!
# Congrats! You made it to the end of the 'regular' part of this first section. Below you will find extra assignments that dive a bit deeper into how well your model performes. If you have ample time, feel free to play around with them. However, the model-based agent is just around the corner, in Section 2. Up to you!

# %% [markdown]
# ### Extra assigment 1: Finding the best model and most profitable task
# If you have time, you can try to answer these additional questions:
# 1. Investigate how beta and alpha value influence the percentage of trials with a reward. Is a high or low learning rate ideal? And a high or low beta?
#
# 2. Investigate whether it matters how quickly the reward probabilities change from trial to trial. If the drift rate is high, would you want a high or a low learning rate? Generate some hypotheses, and try to test them with the code. (Think about where you would alter the drift rate of the reward probabilities)

# %%
results_percentages_beta = np.zeros(len(beta_range))
results_percentages_alpha = np.zeros(len(alpha_range))

def calculate_rewards():
    alpha_range = np.arange(0,1,0.1)
    beta_range = [x for x in range(6)]

    # Loop over alpha range
    for index in range(len(alpha_range)):
        n_trials = 20000
        alpha = alpha_range[index]
        beta = 4
        [stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)
        results_percentages_alpha[index] = sum(rewards)*100 / n_trials



    # Loop over beta range
    for index in range(len(beta_range)):
        n_trials = 20000
        alpha = 0.5
        beta = beta_range[index]
        [stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)
        results_percentages_beta[index] = sum(rewards)*100 / n_trials

        
calculate_rewards()      
print(results_percentages_alpha)  

print(results_percentages_beta)
# Out:
# [50.06  51.585 51.685 54.065 52.8   54.115 52.89  52.725 54.79  53.755]
# [49.615 51.965 52.17  53.21  52.62  55.04 ]

# %%
def plot_results():  
    fig, axs = plt.subplots(2,figsize=(10,10))
    fig.suptitle(f'Percentage of rewards over changing alpha and beta rates')
    axs[0].set_title("Percentage of rewards over increasing alpha rate")
    axs[0].set_xlabel("Alpha value")
    axs[0].set_ylabel("Percentage")
    axs[1].set_xlabel("Beta value")
    axs[1].set_ylabel("Percentage")
    axs[1].set_title("Percentage of rewards over increasing beta rate")

    for i in range(10):
        print("run", i)
        calculate_rewards()
        axs[0].plot(alpha_range, results_percentages_alpha, label=f"run {i}")
        axs[1].plot(beta_range, results_percentages_beta, label=f"run {i}")
        axs[0].legend(loc="upper right")
        axs[1].legend(loc="upper right")

    fig.tight_layout()

# %%
# Create plots for comparison (running takes approx. 30 sec)
plot_results()
# Out:
# run 0
# run 1
# run 2
# run 3
# run 4
# run 5
# run 6
# run 7
# run 8
# run 9

# %%
results_percentages_beta = np.zeros(len(beta_range))
results_percentages_alpha = np.zeros(len(alpha_range))

def plot_difs():
    alpha_range = np.arange(0,1,0.1)
    beta_range = [x for x in range(6)]

    # Loop over alpha range
    for index in range(len(alpha_range)):
        n_trials = 20000
        alpha = alpha_range[index]
        beta = 4
        [stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)
        
        # calculate group scores
        df = pd.DataFrame({"Spaceship_State_Sim":state_sim,"Previous_Rewards":prev_rews,"Stay":stay})
        plot_data = df.groupby(["Spaceship_State_Sim","Previous_Rewards"]).mean().unstack()
        a = plot_data.reset_index()

        # plot the graph
        fig, ax = plt.subplots()
        a.plot(x = "Spaceship_State_Sim", kind="bar", ylim = [0.5,0.9],
               stacked=False,ax=ax)

        ax.legend(["Loss","Win"])
        ax.set_ylabel("Stay Probability", size = 14)
        plt.xticks(rotation=1)
        ax.set_xticklabels(['Different','Same'])
        ax.set_xlabel("Starting state: current vs previous", size = 14)
        ax.invert_xaxis()
        plt.title(f'Simulated model-free agent for alpha = {alpha_range[index]}', size = 16)
        plt.show()



    # Loop over beta range
    for index in range(len(beta_range)):
        n_trials = 20000
        alpha = 0.5
        beta = beta_range[index]
        [stay, state_sim, prev_rews, rewards] = model_free_agent(n_trials, alpha, beta)
        
        # calculate group scores
        df = pd.DataFrame({"Spaceship_State_Sim":state_sim,"Previous_Rewards":prev_rews,"Stay":stay})
        plot_data = df.groupby(["Spaceship_State_Sim","Previous_Rewards"]).mean().unstack()
        a = plot_data.reset_index()

        # plot the graph
        fig, ax = plt.subplots()
        a.plot(x = "Spaceship_State_Sim", kind="bar", ylim = [0.5,0.9],
               stacked=False,ax=ax)

        ax.legend(["Loss","Win"])
        ax.set_ylabel("Stay Probability", size = 14)
        plt.xticks(rotation=1)
        ax.set_xticklabels(['Different','Same'])
        ax.set_xlabel("Starting state: current vs previous", size = 14)
        ax.invert_xaxis()
        plt.title(f'Simulated model-free agent for beta = {beta_range[index]}', size = 16)
        plt.show()

# %%
plot_difs()

# %%
# Here we check for different drifts (low and high) the different alphas (plots)
# The function is a copy of the previous function, but with added d_rate parameter for drift rate

random.seed(2) # fixing the random seed so we can generate similar values

def model_free_agent_2(n_trials, alpha, beta, d_rate):
    
    # we can set the same random seed so we get the same random values
    random.seed(2)
    
    # We'll use your generate_rewards function to generate drifting reward probabilities
    bounds = [0, 1]
    init_vals = [0.4, 0.6]
    drift_rate = d_rate
    reward_probs = generate_rewards(n_trials, bounds, init_vals, drift_rate)
        
    # Pre-allocate empty arrays for storing data
    prev_rews = np.zeros(n_trials) # This will store the rewards won on the previous trial
    first_stage_state = np.zeros(n_trials) # ... which spaceship pair the participants saw (0 or 1)
    state_sim = np.zeros(n_trials) # ... whether participants saw the same spaceship pair as on the previous trial, or the other one 
    choices = np.zeros(n_trials) # ... which spaceship the participants chose
    second_stage_state = np.zeros(n_trials) # ... which planet the participants transitioned to
    stay = np.zeros(n_trials) # ... whether participants visited the same planet as on the previous trial
    rewards = np.zeros(n_trials) # ... how many rewards the participants won on this trial

    # We initialise model-free values for the spaceships (all 0.5)
    Qmf1 = np.zeros((2,2)) + 0.5 # this will create an array inside an array (4 values, you can print them below to see)
    
    # and for the planets
    Qmf2 = np.full(2, 0.5)
    
    # Now, we loop through the trials, making choices, observing outcomes, and updating action values
    for i, reward_prob in enumerate(reward_probs): # for each iteration of this loop, the current trial is indexed by i

        # We randomly start with spaceship pair 1 (0) or pair 2 (1)
        s1 = np.random.choice([0, 1])
        
        # Compute the action probabilities for both spaceships (left: 0, right: 1). The Q-values of the current first-stage state are stored in Qmf1[s1]
        p = softmax(Qmf1[s1], beta) #--- Fill this in (beta??)

        # Make a 'weighted' choice using the np.random.uniform function and the variable p (you can use help(function) 
        # to find out more). In other words, choose the left spaceship (choice==0) with probability p[0] 
        # and the right (choice==1) with probability p[1]
        # You will need to write your code inside the brackets of the int() function, because otherwise Python will complain.
        choice = int(np.random.uniform(0,1) > p[0])                                  #--- Fill this in
        
        # Make the transition to the planet. Take a look at the diagram above. Think about which choices go which second-stage states.
        # This line of code should be _very_ simple.
        s2 = choice                                      #--- Fill this in

        # Calculate the first prediction error (no reward here (r==0), why?). The value of the chosen first-stage state is stored in Qmf1[s1,choice].
        # value in second state minus the value of the first state predicted
        pe_1 = Qmf2[s2] - Qmf1[s1,choice]       #--- Fill this in
        
        # Update the Q-value of the chosen spaceship in the starting state
        # update values = td rule
        Qmf1[s1,choice] = td_rule(alpha, Qmf1[s1,choice], pe_1)                         #--- Fill this in
        
        # Use np.random.uniform to determine whether the agent receives a reward (1 or 0, depending on the reward probability).
        # Note that you will have to use i and s2 to retrieve the current reward probability.
        # Again, You will need to write your code inside the brackets of the int() function.
        r =   int(np.random.uniform(0,1) < reward_probs[i,s2])                                     #--- Fill this in
        
        # Calculate the second prediction error. Again, note that there is a reward value here, but no future reward.
        pe_2 = r - Qmf2[s2]                                    #--- Fill this in
        
        # Update the Q-value of the visited alien (stored in Qmf2) using pe_2
        Qmf2[s2] =  td_rule(alpha, Qmf2[s2], pe_2)                               #--- Fill this in
        
        # Use pe_2 to also update the Q-value of the chosen spaceship in the starting state
        Qmf1[s1,choice] =  td_rule(alpha, Qmf1[s1,choice],pe_2)                        #--- Fill this in

        
        # save data from this trial to our pre-allocated arrays
        rewards[i] = r
        first_stage_state[i] = s1 # we log these so we can check the state similarity
        second_stage_state[i] = s2 # we log these so we can check if participants 'stayed' or 'switched'
        
        # these are based on the previous trial (i-1)
        if i != 0: # start at second trial (first trial this is set to 0)
            # whether they transitioned to the same planet on this trial
            if s2 == second_stage_state[i-1]:
                stay[i] = 1
            # whether they saw the same spaceship pair on this trial
            if s1 == first_stage_state[i-1]:
                state_sim[i] = 1
            # whether they received a reward on the previous trial
            prev_rews[i] = rewards[i-1]
    # data returned by function
    return stay, state_sim, prev_rews, rewards

# %%
drift_rates = [0.2,0.5,0.8]
alpha_range = np.arange(0,1,0.1)
results_percentages_alpha = np.zeros(len(alpha_range))

#   This function will calculate and plot the different reward percentages for the rates in the drift_rates list      
def drift_rates_function():
    fig, axs = plt.subplots(3,figsize=(10,10))
    fig.suptitle(f'Percentage per learning rate for changing drift rate')
    axs[0].set_title("Percentage of rewards over a changing alpha rate with drift rate = 0.2")
    axs[0].set_xlabel("Alpha value")
    axs[0].set_ylabel("Percentage")
    axs[1].set_xlabel("Alpha value")
    axs[1].set_ylabel("Percentage")
    axs[1].set_title("Percentage of rewards over a changing alpha rate with drift rate = 0.5")
    axs[2].set_xlabel("Alpha value")
    axs[2].set_ylabel("Percentage")
    axs[2].set_title("Percentage of rewards over a changing alpha rate with drift rate = 0.8")
    
    for x in range(10):
        for d_index in range(len(drift_rates)):
            # Loop over alpha range
            for index in range(len(alpha_range)):
#                 Uncomment for debug:
#                 print("Run", x) 
                n_trials = 20000
                alpha = alpha_range[index]
                beta = 4
                [stay, state_sim, prev_rews, rewards] = model_free_agent_2(n_trials, alpha, beta,drift_rates[d_index])
                results_percentages_alpha[index] = sum(rewards)*100 / n_trials
            axs[d_index].plot(alpha_range, results_percentages_alpha, label=f"run {x}")
            axs[d_index].legend(loc="upper right")
    fig.tight_layout()

drift_rates_function()

# %% [markdown]
# ### Extra assignment 2: Tracking the reward probabilities
# Another way to look at the performance of the model is to see how well the Q-values track the reward probilities. After all, the model-free agent is simply trying to estimate how good each option is. The better its estimates are, the better its choices become.
#
# Let's see how well your model does. To do this, you are going to rewrite the model-free agent function below. This will essentially be the same function, except that we are now returning some new variables:
#
# - The Q-values of the alients (planets) for each trial in an array called <code>Qs</code>.
# - The true reward probabilities (<code>reward_probs</code>)
# - The choices the agent makes on each trial (<code>choices</code>)
#
# We can use almost exactly the same function as above. All you need to change is to save the variables mentioned above. You don't need to think hard about this part!
#
# You should pre-allocate the variables and then add values to them for every trial. Think about what shapes the variables should take (e.g. how many choices per trial? how many Q-values for each alien per trial?). Hint: you can access a horizontal slice in an array with <code>Qs[:,i]</code>.
#
# You can find the code to generate the plots that show how well the Q-values track the reward probabilities below this cell, so you can look at the real choices your agent made over the trials, and how well they tracked the values of the planets over time!

# %%
def model_free_agent_Qs(n_trials, alpha, beta):
    
    # we can set the same random seed so we get the same random values
    random.seed(2)
    
    # We'll use your generate_rewards function to generate drifting reward probabilities
    bounds = [0, 1]
    init_vals = [0.4, 0.6]
    drift_rate = 0.2
    reward_probs = generate_rewards(n_trials, bounds, init_vals, drift_rate)
    
    # Pre-allocate empty arrays for the data
    
    choices = np.zeros(n_trials) # which spaceship the participants chose
    rewards = np.zeros(n_trials) # how many rewards the participants won on this trial
    Qs =                         # the Q-values on each trial      #--- Fill this in
    
    # Initialise model-free values for the spaceships
    Qmf1 = np.zeros((2,2)) + 0.5 # this will create an array inside an array (4 values, you can print them below to see)
    # and for the planets
    Qmf2 = np.full(2, 0.5)
    
    # Now, we loop through the trials, making choices
    for i, reward_prob in enumerate(reward_probs):

       # Randomly start in spaceship pair 1 (0) or pair 2 (1)
        s1 = np.random.choice([0, 1])
        
        # Agent makes a choice using softmax
        p =                                     #--- Copy from your function above 

        # Make a weighted choice using the np.random.choice function and the variable p (you can use help(function)
        # to find out more)
        choice = choices[i] =                   #--- Copy from your function above (Note, we also save choices[i] here)
        
        # Make the transition to the planet
        s2 = choice # finish this line to transition to the right planet

        # Calculate first prediction error (no reward here (0))
        pe_1 =                                  #--- Copy from your function above
        
        # update choice
        Qmf1[s1,choice] =                       #--- Copy from your function above
        
        # Agent receives a reward (1 or 0) (depending on reward probability)
        r = rewards[i] =                        #--- Copy from your function above (Note, we also save rewards[i] here)
        
        # Calculate second prediction error (actual reward)
        pe_2 =                                  #--- Copy from your function above
        
        # update value of alien (planet)
        Qmf2[s2] =                              #--- Copy from your function above
        
        # update value of choice (spaceship)
        Qmf1[s1,choice] =                       #--- Copy from your function above 
            
        # save q values
        # you need to save 2 q-values for every trial, which are the same q-values as for the second stage (alien/planet) 
        Qs[:,i] =                                                   #--- Fill this in
        
        
    # data returned by function
    return choices, Qs, reward_probs

# %% [markdown]
# Below is the code that plots the Q-values of the model and the actual reward probabilities over time.
#
# <mark>We encourage you to play around with the learning rate and the inverse temperature to see how this affects how well the Q-values reflect the true reward probabilities. Can you relate this to your experimentation with the more blunt performance score above? How do you see which planet was visited on which trial?</mark>

# %%
# we can plot how well this model did at tracking the highest probability of receiving a reward

# set values
n_trials = 200
alpha = 0.5
beta = 4

# run the agent
choices, Qs, reward_probs = model_free_agent_Qs(n_trials, alpha, beta)

colors = ['red','purple']

# Define plot sizes
fig, ax = plt.subplots(figsize=(15, 4), facecolor='w')
ax = plt.subplot2grid((3, 1), (0, 0), colspan=1, rowspan=2)

# plot the Q-values
for i, (i, color) in enumerate(zip(range(2), colors)):
    ax.plot(np.arange(n_trials), Qs[i, :], alpha = 0.8, label = 'Q-value ' + str(i+1), color = color)
    
# defining some plot stuff
ax.set_ylim(0, 1)
ax.set_xlim(0, n_trials)
ax.set_xticks([]) # don't show xticks for this plot
ax.set_ylabel('Q-values')
ax.legend()

# Overlay reward values
for i, (i, color) in enumerate(zip(range(2), colors)):
    if i == 0:
        label_ = 'Red planet'
    else:
        label_ = 'Purple planet'
                
    ax.plot(np.arange(n_trials), reward_probs[:,i], alpha = 0.6, linestyle = '--', label = label_, color = color)
    

# adding some labels and legends
ax.set_ylabel('Probability of reward')
ax.set_title(r'Model-free tracking of values for planet and true reward probabilities', fontweight='bold')
ax.legend(loc=1)

# plot the choices the agent made (either red or purple planet)
ax = plt.subplot2grid((3, 1), (2, 0), colspan=1, rowspan=1)
for i, choice in enumerate(choices):
    ax.scatter(i, 0, color=colors[int(choice)], s=15, alpha = 0.8)
    
# defining some plot stuff
ax.set_xlim(0, n_trials)
ax.set_yticks([]) # no y-ticks for this plot
ax.set_xlabel('Trials')
ax.set_ylabel('Choices')
plt.tight_layout()

# %% [markdown]
# ### Well done! You have finished the extra assignments for this step, amazing work!
#
# Now, you can head over to the script for Step 2, where we will add a parameter to this model that allows us to generate both model-free and model-based behavior on the task!
